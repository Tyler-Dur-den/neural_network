# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris(as_frame=True)
X = iris.data[["petal length (cm)", "petal width (cm)"]].values
y = iris.target == 0

per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)

X_new = [[2,0.5], [3,1]]
y_pred = per_clf.predict(X_new)
print(y_pred)
# Out:
# [ True False]

# %%
try:
    from sklearn.metrics import root_mean_squared_error
except ImportError:
    from sklearn.metrics import mean_squared_error

    def root_mean_squared_error(labels, predictions):
        return mean_squared_error(labels, predictions, squared=False)

# %%
#Regression MLPs
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

forest_reg = RandomForestRegressor(n_estimators=500, max_features="sqrt",max_depth=30, random_state=42, n_jobs=-1)
mlp_reg = MLPRegressor(hidden_layer_sizes=[50, 50, 50], random_state=42)
pipeline1 = make_pipeline(StandardScaler(), mlp_reg)
pipeline2 = make_pipeline(StandardScaler(), forest_reg)
pipeline1.fit(X_train, y_train)
pipeline2.fit(X_train,y_train)
y_pred1 = pipeline1.predict(X_valid)
y_pred2 = pipeline2.predict(X_valid)
rmse1 = root_mean_squared_error(y_valid, y_pred1)
rmse2 = root_mean_squared_error(y_valid, y_pred2)

# %%
rmse1
# Out:
# 0.505332665796845

# %%
rmse2
# Out:
# 0.4893128843449422

# %%
from sklearn.datasets import load_iris
from sklearn.neural_network import MLPClassifier

iris = load_iris()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    iris.data, iris.target, test_size=0.1, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, test_size=0.1, random_state=42)

mlp_clf = MLPClassifier(hidden_layer_sizes=[5], max_iter=10_000,
                        random_state=42)
pipeline = make_pipeline(StandardScaler(), mlp_clf)
pipeline.fit(X_train, y_train)
accuracy = pipeline.score(X_valid, y_valid)
accuracy
# Out:
# 1.0

# %%
import tensorflow as tf
fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]
# Out:
# c:\Users\atthe\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
X_train.shape
# Out:
# (55000, 28, 28)

# %%
X_train, X_valid, X_test = X_train / 255., X_valid / 255., X_test / 255.

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
tf.random.set_seed(42)
tf.keras.backend.clear_session()
model = tf.keras.Sequential()
model.add(tf.keras.layers.InputLayer(input_shape=[28,28]))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(300, activation="relu"))
model.add(tf.keras.layers.Dense(100, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))
# Out:
# WARNING:tensorflow:From c:\Users\atthe\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# c:\Users\atthe\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 266,610 (1.02 MB)
#  Trainable params: 266,610 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7677 - loss: 0.7077 - val_accuracy: 0.8296 - val_loss: 0.5002
# Epoch 2/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8324 - loss: 0.4836 - val_accuracy: 0.8406 - val_loss: 0.4482
# Epoch 3/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8466 - loss: 0.4392 - val_accuracy: 0.8482 - val_loss: 0.4256
# Epoch 4/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8557 - loss: 0.4121 - val_accuracy: 0.8514 - val_loss: 0.4105
# Epoch 5/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8623 - loss: 0.3918 - val_accuracy: 0.8568 - val_loss: 0.3997
# Epoch 6/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8680 - loss: 0.3757 - val_accuracy: 0.8600 - val_loss: 0.3920
# Epoch 7/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8722 - loss: 0.3621 - val_accuracy: 0.8624 - val_loss: 0.3847
# Epoch 8/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8759 - loss: 0.3503 - val_accuracy: 0.8646 - val_loss: 0.3790
# Epoch 9/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8790 - loss: 0.3397 - val_accuracy: 0.8640 - val_loss: 0.3727
# Epoch 10/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8825 - loss: 0.3302 - val_accuracy: 0.8674 - val_loss: 0.3680
# Epoch 11/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8856 - loss: 0.3214 - val_accuracy: 0.8698 - val_loss: 0.3640
# Epoch 12/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8883 - loss: 0.3133 - val_accuracy: 0.8702 - val_loss: 0.3620
# Epoch 13/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8913 - loss: 0.3057 - val_accuracy: 0.8708 - val_loss: 0.3592
# Epoch 14/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8941 - loss: 0.2987 - val_accuracy: 0.8700 - val_loss: 0.3585
# Epoch 15/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8964 - loss: 0.2921 - val_accuracy: 0.8704 - val_loss: 0.3571
# Epoch 16/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8982 - loss: 0.2859 - val_accuracy: 0.8696 - val_loss: 0.3560
# Epoch 17/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9003 - loss: 0.2799 - val_accuracy: 0.8696 - val_loss: 0.3560
# Epoch 18/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9027 - loss: 0.2741 - val_accuracy: 0.8704 - val_loss: 0.3559
# Epoch 19/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9046 - loss: 0.2687 - val_accuracy: 0.8734 - val_loss: 0.3557
# Epoch 20/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9063 - loss: 0.2636 - val_accuracy: 0.8726 - val_loss: 0.3570
# Epoch 21/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9087 - loss: 0.2586 - val_accuracy: 0.8730 - val_loss: 0.3575
# Epoch 22/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9103 - loss: 0.2537 - val_accuracy: 0.8728 - val_loss: 0.3582
# Epoch 23/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9121 - loss: 0.2491 - val_accuracy: 0.8726 - val_loss: 0.3574
# Epoch 24/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9139 - loss: 0.2444 - val_accuracy: 0.8734 - val_loss: 0.3584
# Epoch 25/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9153 - loss: 0.2399 - val_accuracy: 0.8740 - val_loss: 0.3577
# Epoch 26/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9164 - loss: 0.2357 - val_accuracy: 0.8738 - val_loss: 0.3564
# Epoch 27/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9178 - loss: 0.2315 - val_accuracy: 0.8730 - val_loss: 0.3569
# Epoch 28/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9192 - loss: 0.2275 - val_accuracy: 0.8760 - val_loss: 0.3547
# Epoch 29/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9209 - loss: 0.2235 - val_accuracy: 0.8766 - val_loss: 0.3550
# Epoch 30/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9227 - loss: 0.2196 - val_accuracy: 0.8748 - val_loss: 0.3544

# %%
history.params
# Out:
# {'verbose': 'auto', 'epochs': 30, 'steps': 1719}

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 29], ylim=[0, 1], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8728 - loss: 0.3652
# [0.36524078249931335, 0.8727999925613403]

# %%
housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

# %%
norm_layer = tf.keras.layers.Normalization(input_shape=X_train.shape[1:])
model1 = tf.keras.Sequential([
    norm_layer,
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(1)
    ])
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model1.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])
norm_layer.adapt(X_train)
history1 = model1.fit(X_train, y_train, epochs=20,
                      validation_data=(X_valid,y_valid))
mse_test, rmse_test = model1.evaluate(X_test, y_test)
# Out:
# Epoch 1/20
# c:\Users\atthe\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - RootMeanSquaredError: 0.9539 - loss: 0.9099 - val_RootMeanSquaredError: 0.7187 - val_loss: 0.5166
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6174 - loss: 0.3812 - val_RootMeanSquaredError: 0.6705 - val_loss: 0.4496
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5960 - loss: 0.3552 - val_RootMeanSquaredError: 0.7650 - val_loss: 0.5852
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5894 - loss: 0.3474 - val_RootMeanSquaredError: 0.6720 - val_loss: 0.4516
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5768 - loss: 0.3327 - val_RootMeanSquaredError: 0.7106 - val_loss: 0.5050
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5724 - loss: 0.3276 - val_RootMeanSquaredError: 0.6233 - val_loss: 0.3885
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5646 - loss: 0.3187 - val_RootMeanSquaredError: 0.7115 - val_loss: 0.5062
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5557 - loss: 0.3088 - val_RootMeanSquaredError: 0.5861 - val_loss: 0.3435
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5560 - loss: 0.3091 - val_RootMeanSquaredError: 0.9392 - val_loss: 0.8821
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5497 - loss: 0.3021 - val_RootMeanSquaredError: 0.8800 - val_loss: 0.7745
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5474 - loss: 0.2996 - val_RootMeanSquaredError: 0.5921 - val_loss: 0.3506
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5383 - loss: 0.2898 - val_RootMeanSquaredError: 0.6354 - val_loss: 0.4038
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5380 - loss: 0.2894 - val_RootMeanSquaredError: 0.7234 - val_loss: 0.5233
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5339 - loss: 0.2850 - val_RootMeanSquaredError: 0.8773 - val_loss: 0.7696
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5307 - loss: 0.2816 - val_RootMeanSquaredError: 0.5523 - val_loss: 0.3050
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5255 - loss: 0.2761 - val_RootMeanSquaredError: 0.6858 - val_loss: 0.4703
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5241 - loss: 0.2747 - val_RootMeanSquaredError: 0.5362 - val_loss: 0.2875
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5212 - loss: 0.2717 - val_RootMeanSquaredError: 0.6242 - val_loss: 0.3896
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5193 - loss: 0.2697 - val_RootMeanSquaredError: 0.5568 - val_loss: 0.3101
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5166 - loss: 0.2669 - val_RootMeanSquaredError: 0.7103 - val_loss: 0.5045
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - RootMeanSquaredError: 0.5366 - loss: 0.2879

# %%
mse_test
# Out:
# 0.28793567419052124

# %%
rmse_test
# Out:
# 0.5365963578224182

# %%
normalization_layer = tf.keras.layers.Normalization()
hidden_layer1 = tf.keras.layers.Dense(30, activation="relu")
hidden_layer2 = tf.keras.layers.Dense(30, activation="relu")
concat_layer = tf.keras.layers.Concatenate()
output_layer = tf.keras.layers.Dense(1)

input_ = tf.keras.layers.Input(shape=X_train.shape[1:])
normalized = normalization_layer(input_)
hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)
concat = concat_layer([normalized, hidden2])
output = output_layer(concat)

model = tf.keras.Model(inputs=[input_], outputs=[output])

# %%
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_1     │ (None, 8)         │         17 │ input_layer_2[0]… │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 30)        │        270 │ normalization_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 30)        │        930 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 38)        │          0 │ normalization_1[… │
# │ (Concatenate)       │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1)         │         39 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,256 (4.91 KB)
#  Trainable params: 1,239 (4.84 KB)
#  Non-trainable params: 17 (72.00 B)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])
normalization_layer.adapt(X_train)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
mse_test = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - RootMeanSquaredError: 1.1595 - loss: 1.3444 - val_RootMeanSquaredError: 1.0383 - val_loss: 1.0781
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6780 - loss: 0.4597 - val_RootMeanSquaredError: 0.8929 - val_loss: 0.7973
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6315 - loss: 0.3988 - val_RootMeanSquaredError: 1.0659 - val_loss: 1.1362
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6103 - loss: 0.3725 - val_RootMeanSquaredError: 1.1091 - val_loss: 1.2301
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6077 - loss: 0.3693 - val_RootMeanSquaredError: 1.4677 - val_loss: 2.1543
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5993 - loss: 0.3591 - val_RootMeanSquaredError: 1.7451 - val_loss: 3.0454
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6011 - loss: 0.3613 - val_RootMeanSquaredError: 1.4715 - val_loss: 2.1652
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5902 - loss: 0.3484 - val_RootMeanSquaredError: 1.1655 - val_loss: 1.3583
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5823 - loss: 0.3391 - val_RootMeanSquaredError: 1.0165 - val_loss: 1.0333
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5746 - loss: 0.3301 - val_RootMeanSquaredError: 1.1410 - val_loss: 1.3018
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5769 - loss: 0.3328 - val_RootMeanSquaredError: 1.4779 - val_loss: 2.1843
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5756 - loss: 0.3313 - val_RootMeanSquaredError: 1.3477 - val_loss: 1.8164
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5725 - loss: 0.3278 - val_RootMeanSquaredError: 1.2749 - val_loss: 1.6253
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5661 - loss: 0.3205 - val_RootMeanSquaredError: 1.3029 - val_loss: 1.6975
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5656 - loss: 0.3200 - val_RootMeanSquaredError: 1.4080 - val_loss: 1.9824
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5642 - loss: 0.3184 - val_RootMeanSquaredError: 1.4977 - val_loss: 2.2431
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5639 - loss: 0.3179 - val_RootMeanSquaredError: 1.5307 - val_loss: 2.3432
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5633 - loss: 0.3173 - val_RootMeanSquaredError: 1.3757 - val_loss: 1.8925
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5567 - loss: 0.3099 - val_RootMeanSquaredError: 1.2151 - val_loss: 1.4764
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5554 - loss: 0.3085 - val_RootMeanSquaredError: 1.6668 - val_loss: 2.7782
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - RootMeanSquaredError: 0.5628 - loss: 0.3168

# %%
input_wide = tf.keras.layers.Input(shape=[5])  # features 0 to 4
input_deep = tf.keras.layers.Input(shape=[6])  # features 2 to 7
norm_layer_wide = tf.keras.layers.Normalization()
norm_layer_deep = tf.keras.layers.Normalization()
norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)
hidden1 = tf.keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation="relu")(hidden1)
concat = tf.keras.layers.concatenate([norm_wide, hidden2])
output = tf.keras.layers.Dense(1)(concat)
model = tf.keras.Model(inputs=[input_wide, input_deep], outputs=[output])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])

X_train_wide, X_train_deep = X_train[:, :5], X_train[:, 2:]
X_valid_wide, X_valid_deep = X_valid[:, :5], X_valid[:, 2:]
X_test_wide, X_test_deep = X_test[:, :5], X_test[:, 2:]
X_new_wide, X_new_deep = X_test_wide[:3], X_test_deep[:3]

norm_layer_wide.adapt(X_train_wide)
norm_layer_deep.adapt(X_train_deep)
history = model.fit((X_train_wide, X_train_deep), y_train, epochs=20,
                    validation_data=((X_valid_wide, X_valid_deep), y_valid))
mse_test = model.evaluate((X_test_wide, X_test_deep), y_test)
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - RootMeanSquaredError: 1.2425 - loss: 1.5438 - val_RootMeanSquaredError: 0.7780 - val_loss: 0.6053
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6983 - loss: 0.4876 - val_RootMeanSquaredError: 0.6993 - val_loss: 0.4890
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6574 - loss: 0.4321 - val_RootMeanSquaredError: 1.1313 - val_loss: 1.2798
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6313 - loss: 0.3985 - val_RootMeanSquaredError: 1.2623 - val_loss: 1.5934
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6240 - loss: 0.3894 - val_RootMeanSquaredError: 1.2599 - val_loss: 1.5872
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6157 - loss: 0.3791 - val_RootMeanSquaredError: 1.4431 - val_loss: 2.0825
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6127 - loss: 0.3754 - val_RootMeanSquaredError: 1.1230 - val_loss: 1.2612
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6029 - loss: 0.3635 - val_RootMeanSquaredError: 1.2085 - val_loss: 1.4604
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6005 - loss: 0.3606 - val_RootMeanSquaredError: 1.0717 - val_loss: 1.1485
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5950 - loss: 0.3540 - val_RootMeanSquaredError: 1.2774 - val_loss: 1.6317
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5935 - loss: 0.3523 - val_RootMeanSquaredError: 1.4396 - val_loss: 2.0724
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5929 - loss: 0.3516 - val_RootMeanSquaredError: 1.7590 - val_loss: 3.0940
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5962 - loss: 0.3555 - val_RootMeanSquaredError: 1.2736 - val_loss: 1.6222
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5871 - loss: 0.3447 - val_RootMeanSquaredError: 1.1377 - val_loss: 1.2943
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5819 - loss: 0.3386 - val_RootMeanSquaredError: 0.8163 - val_loss: 0.6663
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5772 - loss: 0.3331 - val_RootMeanSquaredError: 0.9174 - val_loss: 0.8417
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5761 - loss: 0.3319 - val_RootMeanSquaredError: 0.8273 - val_loss: 0.6845
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5751 - loss: 0.3307 - val_RootMeanSquaredError: 0.9847 - val_loss: 0.9697
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5751 - loss: 0.3307 - val_RootMeanSquaredError: 0.9676 - val_loss: 0.9363
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5739 - loss: 0.3293 - val_RootMeanSquaredError: 1.1439 - val_loss: 1.3085
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - RootMeanSquaredError: 0.5707 - loss: 0.3257

# %%
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]

# %%
import keras_tuner as kt

def bulid_model(hp):
    n_hidden = hp.Int("n_hidden",min_value=0,max_value=8,default=2)
    n_neurons = hp.Int("n_neuron",min_value=16,max_value=256)
    learning_rate = hp.Float("learning_rate", min_value=1e-4, max_value=1e-2, sampling="log")
    optimizer = hp.Choice("optimizer", values=["sgd","adam"])
    if optimizer == "sgd":
        optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
    else:
        optimizer = tf.keras.optimizers.Adam(learning_rate==learning_rate)
    
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten())
    for _ in range (n_hidden):
        model.add(tf.keras.layers.Dense(n_neurons, activation="relu"))
    model.add(tf.keras.layers.Dense(10, activation="softmax"))
    model.compile(loss="sparse_categorical_crossentropy",optimizer=optimizer,
                  metrics=["accuracy"])
    return model

# %%
random_search_tuner = kt.RandomSearch(
    bulid_model, objective="val_accuracy", max_trials=5, overwrite=True, 
    directory="my_fashion_mnist", project_name="my_rnd_search", seed=42)
random_search_tuner.search(X_train, y_train, epochs=9,
                           validation_data=(X_valid, y_valid))
# Out:
# Trial 5 Complete [00h 00m 18s]
# val_accuracy: 0.8217999935150146
#
# Best val_accuracy So Far: 0.8537999987602234
# Total elapsed time: 00h 01m 18s

# %%
top3_model = random_search_tuner.get_best_models(num_models=3)
best_model = top3_model[0]

# %%
top3_params = random_search_tuner.get_best_hyperparameters(num_trials=3)
top3_params[0].values
# Out:
# {'n_hidden': 7,
#  'n_neuron': 100,
#  'learning_rate': 0.0012482904754698163,
#  'optimizer': 'sgd'}

# %%
best_trial = random_search_tuner.oracle.get_best_trials(num_trials=1)[0]
best_trial.summary()
# Out:
# Trial 1 summary
# Hyperparameters:
# n_hidden: 7
# n_neuron: 100
# learning_rate: 0.0012482904754698163
# optimizer: sgd
# Score: 0.8537999987602234

# %%
best_model.fit(X_train_full, y_train_full, epochs=10)
test_loss, test_accuracy = best_model.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8716 - loss: 0.3442
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8787 - loss: 0.3298
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8826 - loss: 0.3187
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8866 - loss: 0.3088
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8889 - loss: 0.2995
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8921 - loss: 0.2907
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8947 - loss: 0.2835
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8969 - loss: 0.2768
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8993 - loss: 0.2709
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9023 - loss: 0.2641
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.8444 - loss: 0.4517
