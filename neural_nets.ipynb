# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris(as_frame=True)
X = iris.data[["petal length (cm)", "petal width (cm)"]].values
y = iris.target == 0

per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)

X_new = [[2,0.5], [3,1]]
y_pred = per_clf.predict(X_new)
print(y_pred)
# Out:
# [ True False]

# %%
try:
    from sklearn.metrics import root_mean_squared_error
except ImportError:
    from sklearn.metrics import mean_squared_error

    def root_mean_squared_error(labels, predictions):
        return mean_squared_error(labels, predictions, squared=False)

# %%
#Regression MLPs
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

forest_reg = RandomForestRegressor(n_estimators=500, max_features="sqrt",max_depth=30, random_state=42, n_jobs=-1)
mlp_reg = MLPRegressor(hidden_layer_sizes=[50, 50, 50], random_state=42)
pipeline1 = make_pipeline(StandardScaler(), mlp_reg)
pipeline2 = make_pipeline(StandardScaler(), forest_reg)
pipeline1.fit(X_train, y_train)
pipeline2.fit(X_train,y_train)
y_pred1 = pipeline1.predict(X_valid)
y_pred2 = pipeline2.predict(X_valid)
rmse1 = root_mean_squared_error(y_valid, y_pred1)
rmse2 = root_mean_squared_error(y_valid, y_pred2)

# %%
rmse1
# Out:
# 0.505332665796845

# %%
rmse2
# Out:
# 0.4893128843449422

# %%
from sklearn.datasets import load_iris
from sklearn.neural_network import MLPClassifier

iris = load_iris()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    iris.data, iris.target, test_size=0.1, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, test_size=0.1, random_state=42)

mlp_clf = MLPClassifier(hidden_layer_sizes=[5], max_iter=10_000,
                        random_state=42)
pipeline = make_pipeline(StandardScaler(), mlp_clf)
pipeline.fit(X_train, y_train)
accuracy = pipeline.score(X_valid, y_valid)
accuracy
# Out:
# 1.0

# %%
import tensorflow as tf
fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]
# Out:
# c:\Users\atthe\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
X_train.shape
# Out:
# (55000, 28, 28)

# %%
X_train, X_valid, X_test = X_train / 255., X_valid / 255., X_test / 255.

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
tf.random.set_seed(42)
tf.keras.backend.clear_session()
model = tf.keras.Sequential()
model.add(tf.keras.layers.InputLayer(input_shape=[28,28]))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(300, activation="relu"))
model.add(tf.keras.layers.Dense(100, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))
# Out:
# WARNING:tensorflow:From c:\Users\atthe\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# c:\Users\atthe\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 266,610 (1.02 MB)
#  Trainable params: 266,610 (1.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7598 - loss: 0.7379 - val_accuracy: 0.8234 - val_loss: 0.5128
# Epoch 2/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8316 - loss: 0.4875 - val_accuracy: 0.8416 - val_loss: 0.4563
# Epoch 3/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8463 - loss: 0.4402 - val_accuracy: 0.8474 - val_loss: 0.4300
# Epoch 4/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8568 - loss: 0.4123 - val_accuracy: 0.8538 - val_loss: 0.4139
# Epoch 5/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8633 - loss: 0.3921 - val_accuracy: 0.8552 - val_loss: 0.4017
# Epoch 6/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8681 - loss: 0.3764 - val_accuracy: 0.8588 - val_loss: 0.3918
# Epoch 7/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8728 - loss: 0.3630 - val_accuracy: 0.8622 - val_loss: 0.3821
# Epoch 8/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8764 - loss: 0.3512 - val_accuracy: 0.8654 - val_loss: 0.3741
# Epoch 9/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8796 - loss: 0.3410 - val_accuracy: 0.8664 - val_loss: 0.3680
# Epoch 10/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8830 - loss: 0.3318 - val_accuracy: 0.8694 - val_loss: 0.3621
# Epoch 11/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8853 - loss: 0.3230 - val_accuracy: 0.8702 - val_loss: 0.3568
# Epoch 12/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8879 - loss: 0.3150 - val_accuracy: 0.8708 - val_loss: 0.3541
# Epoch 13/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8908 - loss: 0.3076 - val_accuracy: 0.8726 - val_loss: 0.3512
# Epoch 14/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8931 - loss: 0.3005 - val_accuracy: 0.8724 - val_loss: 0.3486
# Epoch 15/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8956 - loss: 0.2940 - val_accuracy: 0.8734 - val_loss: 0.3457
# Epoch 16/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8972 - loss: 0.2877 - val_accuracy: 0.8740 - val_loss: 0.3429
# Epoch 17/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8990 - loss: 0.2818 - val_accuracy: 0.8732 - val_loss: 0.3416
# Epoch 18/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9011 - loss: 0.2762 - val_accuracy: 0.8736 - val_loss: 0.3412
# Epoch 19/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9025 - loss: 0.2710 - val_accuracy: 0.8736 - val_loss: 0.3395
# Epoch 20/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9043 - loss: 0.2659 - val_accuracy: 0.8744 - val_loss: 0.3384
# Epoch 21/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9058 - loss: 0.2611 - val_accuracy: 0.8752 - val_loss: 0.3379
# Epoch 22/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9078 - loss: 0.2564 - val_accuracy: 0.8766 - val_loss: 0.3372
# Epoch 23/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9093 - loss: 0.2520 - val_accuracy: 0.8758 - val_loss: 0.3377
# Epoch 24/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9114 - loss: 0.2476 - val_accuracy: 0.8774 - val_loss: 0.3379
# Epoch 25/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9128 - loss: 0.2434 - val_accuracy: 0.8778 - val_loss: 0.3366
# Epoch 26/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9146 - loss: 0.2391 - val_accuracy: 0.8768 - val_loss: 0.3380
# Epoch 27/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9158 - loss: 0.2351 - val_accuracy: 0.8780 - val_loss: 0.3385
# Epoch 28/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9173 - loss: 0.2312 - val_accuracy: 0.8762 - val_loss: 0.3385
# Epoch 29/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9191 - loss: 0.2274 - val_accuracy: 0.8768 - val_loss: 0.3385
# Epoch 30/30
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9208 - loss: 0.2236 - val_accuracy: 0.8774 - val_loss: 0.3392

# %%
history.params
# Out:
# {'verbose': 'auto', 'epochs': 30, 'steps': 1719}

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 29], ylim=[0, 1], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8730 - loss: 0.3625
# [0.36249828338623047, 0.8730000257492065]

# %%
housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

# %%
norm_layer = tf.keras.layers.Normalization(input_shape=X_train.shape[1:])
model1 = tf.keras.Sequential([
    norm_layer,
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(50, activation="relu"),
    tf.keras.layers.Dense(1)
    ])
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model1.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])
norm_layer.adapt(X_train)
history1 = model1.fit(X_train, y_train, epochs=20,
                      validation_data=(X_valid,y_valid))
mse_test, rmse_test = model1.evaluate(X_test, y_test)
# Out:
# Epoch 1/20
# c:\Users\atthe\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - RootMeanSquaredError: 0.8828 - loss: 0.7793 - val_RootMeanSquaredError: 0.7574 - val_loss: 0.5736
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6088 - loss: 0.3706 - val_RootMeanSquaredError: 0.5875 - val_loss: 0.3452
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5927 - loss: 0.3513 - val_RootMeanSquaredError: 0.6882 - val_loss: 0.4737
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5845 - loss: 0.3417 - val_RootMeanSquaredError: 1.2142 - val_loss: 1.4744
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5772 - loss: 0.3332 - val_RootMeanSquaredError: 1.6378 - val_loss: 2.6824
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5825 - loss: 0.3393 - val_RootMeanSquaredError: 1.2113 - val_loss: 1.4671
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5704 - loss: 0.3254 - val_RootMeanSquaredError: 0.9037 - val_loss: 0.8167
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5598 - loss: 0.3134 - val_RootMeanSquaredError: 0.6913 - val_loss: 0.4779
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5518 - loss: 0.3045 - val_RootMeanSquaredError: 0.6716 - val_loss: 0.4511
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5468 - loss: 0.2990 - val_RootMeanSquaredError: 0.5830 - val_loss: 0.3399
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5421 - loss: 0.2938 - val_RootMeanSquaredError: 0.6702 - val_loss: 0.4491
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5389 - loss: 0.2904 - val_RootMeanSquaredError: 0.5512 - val_loss: 0.3039
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5349 - loss: 0.2862 - val_RootMeanSquaredError: 0.6392 - val_loss: 0.4086
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5336 - loss: 0.2847 - val_RootMeanSquaredError: 0.5739 - val_loss: 0.3294
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5291 - loss: 0.2799 - val_RootMeanSquaredError: 0.6367 - val_loss: 0.4054
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5310 - loss: 0.2820 - val_RootMeanSquaredError: 0.6464 - val_loss: 0.4179
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5257 - loss: 0.2764 - val_RootMeanSquaredError: 1.2215 - val_loss: 1.4920
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5292 - loss: 0.2801 - val_RootMeanSquaredError: 0.8715 - val_loss: 0.7595
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5224 - loss: 0.2730 - val_RootMeanSquaredError: 0.7120 - val_loss: 0.5070
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5185 - loss: 0.2689 - val_RootMeanSquaredError: 0.6187 - val_loss: 0.3828
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - RootMeanSquaredError: 0.5303 - loss: 0.2812

# %%
mse_test
# Out:
# 0.2812422215938568

# %%
rmse_test
# Out:
# 0.5303227305412292

# %%
normalization_layer = tf.keras.layers.Normalization()
hidden_layer1 = tf.keras.layers.Dense(30, activation="relu")
hidden_layer2 = tf.keras.layers.Dense(30, activation="relu")
concat_layer = tf.keras.layers.Concatenate()
output_layer = tf.keras.layers.Dense(1)

input_ = tf.keras.layers.Input(shape=X_train.shape[1:])
normalized = normalization_layer(input_)
hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)
concat = concat_layer([normalized, hidden2])
output = output_layer(concat)

model = tf.keras.Model(inputs=[input_], outputs=[output])

# %%
model.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_9     │ (None, 8)         │         17 │ input_layer_8[0]… │
# │ (Normalization)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 30)        │        270 │ normalization_9[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 30)        │        930 │ dense_31[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 38)        │          0 │ normalization_9[… │
# │ (Concatenate)       │                   │            │ dense_32[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 1)         │         39 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,256 (4.91 KB)
#  Trainable params: 1,239 (4.84 KB)
#  Non-trainable params: 17 (72.00 B)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])
normalization_layer.adapt(X_train)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
mse_test = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - RootMeanSquaredError: 1.1442 - loss: 1.3092 - val_RootMeanSquaredError: 0.7577 - val_loss: 0.5741
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6712 - loss: 0.4505 - val_RootMeanSquaredError: 0.6215 - val_loss: 0.3863
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6327 - loss: 0.4003 - val_RootMeanSquaredError: 0.6087 - val_loss: 0.3705
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6166 - loss: 0.3802 - val_RootMeanSquaredError: 0.6083 - val_loss: 0.3700
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6061 - loss: 0.3674 - val_RootMeanSquaredError: 0.6613 - val_loss: 0.4373
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5975 - loss: 0.3571 - val_RootMeanSquaredError: 0.5848 - val_loss: 0.3420
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5915 - loss: 0.3499 - val_RootMeanSquaredError: 0.7485 - val_loss: 0.5602
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5841 - loss: 0.3412 - val_RootMeanSquaredError: 0.8217 - val_loss: 0.6752
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5842 - loss: 0.3412 - val_RootMeanSquaredError: 0.8866 - val_loss: 0.7861
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5763 - loss: 0.3321 - val_RootMeanSquaredError: 0.9987 - val_loss: 0.9975
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5750 - loss: 0.3306 - val_RootMeanSquaredError: 0.7668 - val_loss: 0.5879
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5673 - loss: 0.3219 - val_RootMeanSquaredError: 0.8302 - val_loss: 0.6892
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5653 - loss: 0.3196 - val_RootMeanSquaredError: 0.7549 - val_loss: 0.5699
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5603 - loss: 0.3140 - val_RootMeanSquaredError: 0.9593 - val_loss: 0.9202
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5608 - loss: 0.3145 - val_RootMeanSquaredError: 0.8793 - val_loss: 0.7731
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5591 - loss: 0.3126 - val_RootMeanSquaredError: 0.9473 - val_loss: 0.8974
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5539 - loss: 0.3068 - val_RootMeanSquaredError: 0.6689 - val_loss: 0.4474
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5499 - loss: 0.3024 - val_RootMeanSquaredError: 0.8504 - val_loss: 0.7231
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5495 - loss: 0.3019 - val_RootMeanSquaredError: 0.7061 - val_loss: 0.4986
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5471 - loss: 0.2994 - val_RootMeanSquaredError: 0.8604 - val_loss: 0.7402
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - RootMeanSquaredError: 0.5527 - loss: 0.3054

# %%
input_wide = tf.keras.layers.Input(shape=[5])  # features 0 to 4
input_deep = tf.keras.layers.Input(shape=[6])  # features 2 to 7
norm_layer_wide = tf.keras.layers.Normalization()
norm_layer_deep = tf.keras.layers.Normalization()
norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)
hidden1 = tf.keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation="relu")(hidden1)
concat = tf.keras.layers.concatenate([norm_wide, hidden2])
output = tf.keras.layers.Dense(1)(concat)
model = tf.keras.Model(inputs=[input_wide, input_deep], outputs=[output])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])

X_train_wide, X_train_deep = X_train[:, :5], X_train[:, 2:]
X_valid_wide, X_valid_deep = X_valid[:, :5], X_valid[:, 2:]
X_test_wide, X_test_deep = X_test[:, :5], X_test[:, 2:]
X_new_wide, X_new_deep = X_test_wide[:3], X_test_deep[:3]

norm_layer_wide.adapt(X_train_wide)
norm_layer_deep.adapt(X_train_deep)
history = model.fit((X_train_wide, X_train_deep), y_train, epochs=20,
                    validation_data=((X_valid_wide, X_valid_deep), y_valid))
mse_test = model.evaluate((X_test_wide, X_test_deep), y_test)
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - RootMeanSquaredError: 1.2988 - loss: 1.6868 - val_RootMeanSquaredError: 0.8796 - val_loss: 0.7737
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.7585 - loss: 0.5754 - val_RootMeanSquaredError: 0.6888 - val_loss: 0.4744
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6823 - loss: 0.4656 - val_RootMeanSquaredError: 0.7863 - val_loss: 0.6183
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6455 - loss: 0.4167 - val_RootMeanSquaredError: 0.6158 - val_loss: 0.3793
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6261 - loss: 0.3920 - val_RootMeanSquaredError: 0.9902 - val_loss: 0.9804
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6114 - loss: 0.3738 - val_RootMeanSquaredError: 1.1828 - val_loss: 1.3990
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.6057 - loss: 0.3669 - val_RootMeanSquaredError: 1.1796 - val_loss: 1.3915
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5983 - loss: 0.3579 - val_RootMeanSquaredError: 1.7058 - val_loss: 2.9096
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.6024 - loss: 0.3629 - val_RootMeanSquaredError: 1.9041 - val_loss: 3.6257
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5972 - loss: 0.3566 - val_RootMeanSquaredError: 1.7209 - val_loss: 2.9615
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5959 - loss: 0.3550 - val_RootMeanSquaredError: 1.6056 - val_loss: 2.5781
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5906 - loss: 0.3488 - val_RootMeanSquaredError: 1.6567 - val_loss: 2.7447
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5897 - loss: 0.3477 - val_RootMeanSquaredError: 1.3393 - val_loss: 1.7936
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5824 - loss: 0.3392 - val_RootMeanSquaredError: 1.6043 - val_loss: 2.5736
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - RootMeanSquaredError: 0.5864 - loss: 0.3438 - val_RootMeanSquaredError: 1.5079 - val_loss: 2.2738
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5825 - loss: 0.3393 - val_RootMeanSquaredError: 1.5053 - val_loss: 2.2658
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5812 - loss: 0.3378 - val_RootMeanSquaredError: 1.2026 - val_loss: 1.4463
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5758 - loss: 0.3316 - val_RootMeanSquaredError: 1.1718 - val_loss: 1.3731
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5726 - loss: 0.3279 - val_RootMeanSquaredError: 0.9040 - val_loss: 0.8173
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - RootMeanSquaredError: 0.5676 - loss: 0.3222 - val_RootMeanSquaredError: 0.9681 - val_loss: 0.9372
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - RootMeanSquaredError: 0.5651 - loss: 0.3194
